# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid=c69920e822cf490cd297f2fe22b3255e&units={units}&q="


# set up lists to hold reponse info
city_name = []
clouds = []
country = []
date = []
humidity = []
lat = []
lng = []
temp = []
wind = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        clouds.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        print(f"Processing Records for {city}")
 
    except (KeyError, IndexError):
        print(f"aint got it homie ... skipping {city}.")
# Out:
# Processing Records for kingaroy
# Processing Records for porto novo
# Processing Records for durango
# Processing Records for busselton
# Processing Records for atuona
# Processing Records for senador jose porfirio
# Processing Records for rabo de peixe
# Processing Records for cidreira
# Processing Records for ketchikan
# Processing Records for leh
# aint got it homie ... skipping taolanaro.
# Processing Records for noumea
# aint got it homie ... skipping tuggurt.
# Processing Records for benjamin constant
# Processing Records for gat
# Processing Records for kruisfontein
# Processing Records for puerto ayora
# Processing Records for esperance
# Processing Records for idah
# Processing Records for zhigansk
# Processing Records for soria
# Processing Records for saskylakh
# Processing Records for san patricio
# Processing Records for cape town
# Processing Records for dikson
# Processing Records for harper
# Processing Records for husavik
# Processing Records for namibe
# Processing Records for zyryanka
# Processing Records for west bay
# Processing Records for atar
# Processing Records for east london
# Processing Records for vaini
# Processing Records for bluff
# Processing Records for udachnyy
# Processing Records for aklavik
# Processing Records for severo-kurilsk
# Processing Records for ostrovnoy
# Processing Records for salalah
# Processing Records for ribeira grande
# aint got it homie ... skipping grand river south east.
# Processing Records for alice springs
# Processing Records for jamestown
# Processing Records for khatanga
# Processing Records for provideniya
# Processing Records for walvis bay
# Processing Records for maniitsoq
# Processing Records for barrow
# Processing Records for bredasdorp
# Processing Records for pangody
# aint got it homie ... skipping palabuhanratu.
# Processing Records for camacha
# Processing Records for hilo
# Processing Records for puerto carreno
# Processing Records for yueyang
# Processing Records for punta arenas
# Processing Records for correntina
# Processing Records for odienne
# Processing Records for tasiilaq
# Processing Records for sorland
# aint got it homie ... skipping samusu.
# aint got it homie ... skipping mutsamudu.
# Processing Records for tual
# Processing Records for tura
# Processing Records for bambous virieux
# Processing Records for hinesburg
# Processing Records for mehamn
# Processing Records for codrington
# Processing Records for mahibadhoo
# Processing Records for vuktyl
# Processing Records for mar del plata
# aint got it homie ... skipping belushya guba.
# Processing Records for saint-pierre
# Processing Records for ushuaia
# Processing Records for ixtapa
# Processing Records for kaniama
# aint got it homie ... skipping golden rock.
# aint got it homie ... skipping gorno-chuyskiy.
# Processing Records for nemuro
# Processing Records for mataura
# Processing Records for yellowknife
# Processing Records for vilyuysk
# Processing Records for sagua la grande
# Processing Records for lebu
# Processing Records for rikitea
# Processing Records for acajutla
# Processing Records for araguari
# Processing Records for kandrian
# Processing Records for jiuquan
# Processing Records for tiksi
# Processing Records for georgetown
# Processing Records for mount isa
# Processing Records for chuy
# Processing Records for new norfolk
# Processing Records for haines junction
# Processing Records for ipanema
# Processing Records for luang prabang
# Processing Records for burnie
# Processing Records for shingu
# Processing Records for el retorno
# Processing Records for port alfred
# aint got it homie ... skipping mys shmidta.
# Processing Records for nikolskoye
# Processing Records for nome
# Processing Records for hobart
# Processing Records for the pas
# aint got it homie ... skipping tsihombe.
# Processing Records for airai
# Processing Records for muros
# Processing Records for arraial do cabo
# Processing Records for victoria
# Processing Records for faya
# Processing Records for plettenberg bay
# Processing Records for kloulklubed
# Processing Records for saint-philippe
# Processing Records for coacotla
# Processing Records for edson
# Processing Records for rundu
# Processing Records for zhezkazgan
# Processing Records for sokolo
# Processing Records for kapaa
# Processing Records for damaturu
# Processing Records for isangel
# Processing Records for luderitz
# Processing Records for topolobampo
# aint got it homie ... skipping mustafakemalpasa.
# Processing Records for qaqortoq
# Processing Records for qaanaaq
# Processing Records for waingapu
# Processing Records for nuevitas
# Processing Records for hermanus
# Processing Records for belen
# Processing Records for nanortalik
# Processing Records for ambulu
# Processing Records for kortkeros
# Processing Records for saint anthony
# Processing Records for alanya
# aint got it homie ... skipping illoqqortoormiut.
# Processing Records for biak
# aint got it homie ... skipping barentsburg.
# Processing Records for belaya gora
# Processing Records for saint-claude
# Processing Records for aksarka
# Processing Records for torbay
# Processing Records for talaya
# Processing Records for vostok
# Processing Records for lluta
# Processing Records for ler
# Processing Records for bubaque
# Processing Records for geraldton
# Processing Records for marawi
# Processing Records for avarua
# Processing Records for hithadhoo
# Processing Records for antofagasta
# aint got it homie ... skipping haibowan.
# Processing Records for amherstburg
# Processing Records for darfield
# Processing Records for dovers
# Processing Records for ayan
# Processing Records for paita
# Processing Records for albany
# aint got it homie ... skipping bengkulu.
# aint got it homie ... skipping mullaitivu.
# Processing Records for saldanha
# aint got it homie ... skipping nizhneyansk.
# Processing Records for najran
# Processing Records for solenzo
# Processing Records for baykit
# Processing Records for kodiak
# Processing Records for cabedelo
# Processing Records for iqaluit
# Processing Records for loralai
# Processing Records for iquitos
# Processing Records for kavaratti
# Processing Records for castro
# Processing Records for kaitangata
# aint got it homie ... skipping kazalinsk.
# Processing Records for carnarvon
# Processing Records for rio gallegos
# Processing Records for luganville
# Processing Records for sandpoint
# aint got it homie ... skipping xadani.
# Processing Records for jumla
# Processing Records for san cristobal
# Processing Records for becerril
# Processing Records for roblin
# Processing Records for manzhouli
# aint got it homie ... skipping tasbuget.
# Processing Records for cherskiy
# Processing Records for tayu
# Processing Records for broome
# Processing Records for galesong
# aint got it homie ... skipping attawapiskat.
# Processing Records for ponta do sol
# Processing Records for kenai
# Processing Records for puerto quijarro
# Processing Records for talcahuano
# Processing Records for coahuayana
# Processing Records for coquimbo
# Processing Records for sinegorskiy
# Processing Records for clyde river
# Processing Records for butaritari
# Processing Records for palmer
# Processing Records for mumbwa
# Processing Records for camocim
# Processing Records for ewa beach
# Processing Records for rivadavia
# Processing Records for falam
# Processing Records for leningradskiy
# Processing Records for trofors
# Processing Records for milkovo
# Processing Records for birjand
# Processing Records for ugento
# Processing Records for hami
# Processing Records for morro bay
# Processing Records for anadyr
# Processing Records for chokurdakh
# Processing Records for port blair
# Processing Records for cockburn town
# Processing Records for camacupa
# Processing Records for voznesenye
# Processing Records for bavly
# aint got it homie ... skipping burica.
# Processing Records for vangaindrano
# Processing Records for kalmunai
# Processing Records for karratha
# Processing Records for dutse
# Processing Records for nantucket
# Processing Records for toyooka
# Processing Records for bejar
# Processing Records for tabas
# Processing Records for caravelas
# Processing Records for burla
# Processing Records for vestmannaeyjar
# Processing Records for khasan
# Processing Records for awbari
# aint got it homie ... skipping saleaula.
# Processing Records for sola
# Processing Records for jhang
# Processing Records for talnakh
# Processing Records for staryy nadym
# Processing Records for vila velha
# Processing Records for pangnirtung
# Processing Records for necochea
# Processing Records for betul
# Processing Records for manggar
# Processing Records for reftinskiy
# Processing Records for port elizabeth
# Processing Records for road town
# Processing Records for trelew
# Processing Records for samur
# Processing Records for longyearbyen
# aint got it homie ... skipping viligili.
# Processing Records for san lawrenz
# Processing Records for port hardy
# aint got it homie ... skipping dien bien.
# Processing Records for makakilo city
# Processing Records for vanimo
# Processing Records for aginskoye
# Processing Records for naryan-mar
# Processing Records for mayo
# Processing Records for vung tau
# Processing Records for fairbanks
# Processing Records for barcelona
# Processing Records for shimoda
# aint got it homie ... skipping amderma.
# aint got it homie ... skipping mrirt.
# Processing Records for pervomayskiy
# Processing Records for straseni
# aint got it homie ... skipping bairiki.
# aint got it homie ... skipping schwedt.
# Processing Records for teknaf
# Processing Records for bethel
# Processing Records for pirapora
# Processing Records for khorixas
# Processing Records for port lincoln
# Processing Records for umm kaddadah
# Processing Records for vestmanna
# Processing Records for arman
# Processing Records for bilma
# Processing Records for oum hadjer
# Processing Records for comodoro rivadavia
# Processing Records for mandurah
# Processing Records for monrovia
# Processing Records for komsomolskiy
# Processing Records for sousa
# Processing Records for zambezi
# Processing Records for iskateley
# aint got it homie ... skipping naenwa.
# Processing Records for alvand
# Processing Records for guanaja
# Processing Records for hueyapan
# Processing Records for orlik
# Processing Records for bulaevo
# Processing Records for balabac
# Processing Records for deming
# Processing Records for upernavik
# Processing Records for nouadhibou
# aint got it homie ... skipping ascension.
# aint got it homie ... skipping vaitupu.
# Processing Records for broken hill
# Processing Records for zanjan
# Processing Records for stromness
# aint got it homie ... skipping bur gabo.
# Processing Records for penzance
# Processing Records for kingsville
# Processing Records for atherton
# Processing Records for tuatapere
# Processing Records for pisco
# aint got it homie ... skipping pemangkat.
# Processing Records for key west
# Processing Records for shubarkuduk
# Processing Records for havelock
# Processing Records for grand gaube
# Processing Records for narsaq
# Processing Records for prado
# Processing Records for mackay
# Processing Records for tirur
# Processing Records for gambo
# Processing Records for cabo san lucas
# Processing Records for hamilton
# Processing Records for aitape
# Processing Records for nizhniy odes
# Processing Records for smidovich
# Processing Records for tuktoyaktuk
# Processing Records for anloga
# Processing Records for jacareacanga
# Processing Records for sao borja
# Processing Records for thompson
# Processing Records for prince rupert
# Processing Records for north platte
# Processing Records for kipini
# Processing Records for shagonar
# Processing Records for nioro
# Processing Records for daru
# aint got it homie ... skipping kuche.
# Processing Records for luanda
# Processing Records for bonanza
# Processing Records for laguna
# Processing Records for ashnak
# aint got it homie ... skipping wulanhaote.
# aint got it homie ... skipping duz.
# Processing Records for san borja
# Processing Records for saint-augustin
# Processing Records for port-cartier
# Processing Records for bartica
# Processing Records for klaksvik
# Processing Records for ugoofaaru
# Processing Records for riyadh
# Processing Records for farafangana
# Processing Records for yerbogachen
# Processing Records for bosaso
# Processing Records for basoko
# Processing Records for tilichiki
# aint got it homie ... skipping deh rawud.
# Processing Records for fortuna
# Processing Records for richmond
# Processing Records for margate
# Processing Records for kaeo
# Processing Records for borogontsy
# Processing Records for karpathos
# Processing Records for warragul
# Processing Records for joshimath
# Processing Records for rocha
# Processing Records for ozernovskiy
# Processing Records for crailsheim
# Processing Records for boddam
# Processing Records for thinadhoo
# Processing Records for saint george
# Processing Records for kyzyl-suu
# Processing Records for sinnamary
# Processing Records for beringovskiy
# Processing Records for leon
# Processing Records for mahebourg
# Processing Records for padampur
# Processing Records for sangmelima
# Processing Records for kharp
# Processing Records for aswan
# aint got it homie ... skipping loubomo.
# Processing Records for ambunti
# Processing Records for abaza
# Processing Records for ilulissat
# Processing Records for fort abbas
# Processing Records for birao
# Processing Records for lavrentiya
# Processing Records for dunmore town
# Processing Records for norman wells
# Processing Records for ziro
# Processing Records for puerto escondido
# Processing Records for los llanos de aridane
# Processing Records for abapo
# Processing Records for balkany
# Processing Records for banjar
# Processing Records for katsuura
# Processing Records for mugur-aksy
# Processing Records for camopi
# Processing Records for eunice
# Processing Records for terra santa
# Processing Records for hastings
# Processing Records for turbat
# Processing Records for fort nelson
# Processing Records for xuddur
# Processing Records for pevek
# Processing Records for linxia
# aint got it homie ... skipping marcona.
# Processing Records for linqing
# Processing Records for quatre cocos
# Processing Records for along
# Processing Records for axim
# Processing Records for cap-aux-meules

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#convert data to a DataFrame
weather_dict = {
    "city":city_name,
    "cloudiness":clouds,
    "country":country,
    "date":date,
    "humidity":humidity,
    "lat":lat,
    "lng":lng,
    "max_temp":temp,
    "wind":wind
}

weather_data = pd.DataFrame(weather_dict)
weather_data.head()

# %%
# write DF to CSV
weather_data.to_csv("output_data/cities.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# you like the 80s?
plt.scatter(weather_data["lat"], weather_data["max_temp"], marker="o", facecolors="magenta", edgecolors="darkorchid")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature 11/10/18")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Temperature_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["lat"], weather_data["humidity"], marker="o", facecolors="greenyellow", edgecolors="limegreen")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity 11/10/18")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["lat"], weather_data["cloudiness"], marker="o", facecolors="yellow", edgecolors="gold")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness 11/10/18")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["lat"], weather_data["wind"], marker="o", facecolors="aqua", edgecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed 11/10/18")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeed_Latitude.png")

# Show plot
plt.show()
